# %%
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, FunctionTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import joblib
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, InputLayer
# Out:
# WARNING:tensorflow:From c:\Users\ROG Zephyrus G15\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (2.15.0)
# Requirement already satisfied: tensorflow-intel==2.15.0 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.14.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\rog zephyrus g15\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.15.0->tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.25.8)
# Requirement already satisfied: setuptools in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\rog zephyrus g15\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\rog zephyrus g15\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.15.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.14.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.74.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.40.3)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.9)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.32.5)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2025.8.3)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.6.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow) (0.45.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.0.2)

# %%
df = pd.read_csv('customer_churn_dataset-testing-master.csv')
df.head()
# Out:
#    CustomerID  Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0           1   22  Female      25               14              4
# 1           2   41  Female      28               28              7
# 2           3   47    Male      27               10              2
# 3           4   35    Male       9               12              5
# 4           5   53  Female      58               24              9
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0             27             Basic         Monthly          598
# 1             13          Standard         Monthly          584
# 2             29           Premium          Annual          757
# 3             17           Premium       Quarterly          232
# 4              2          Standard          Annual          533
#
#    Last Interaction  Churn
# 0                 9      1
# 1                20      0
# 2                21      0
# 3                18      0
# 4                18      0

# %%
df.shape #number of rows and columns in the DataFrame.
# Out:
# (64374, 12)

# %%
df['Churn'].replace({0:'No',1 : 'Yes'}, inplace=True) #replacing 0 with No and 1 with Yes in the Churn column.
# Out:
# C:\Users\ROG Zephyrus G15\AppData\Local\Temp\ipykernel_27352\1496509060.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Churn'].replace({0:'No',1 : 'Yes'}, inplace=True) #replacing 0 with No and 1 with Yes in the Churn column.

# %%
df #displaying the DataFrame.
# Out:
#        CustomerID  Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0               1   22  Female      25               14              4
# 1               2   41  Female      28               28              7
# 2               3   47    Male      27               10              2
# 3               4   35    Male       9               12              5
# 4               5   53  Female      58               24              9
# ...           ...  ...     ...     ...              ...            ...
# 64369       64370   45  Female      33               12              6
# 64370       64371   37    Male       6                1              5
# 64371       64372   25    Male      39               14              8
# 64372       64373   50  Female      18               19              7
# 64373       64374   52  Female      45               15              9
#
#        Payment Delay Subscription Type Contract Length  Total Spend  \
# 0                 27             Basic         Monthly          598
# 1                 13          Standard         Monthly          584
# 2                 29           Premium          Annual          757
# 3                 17           Premium       Quarterly          232
# 4                  2          Standard          Annual          533
# ...              ...               ...             ...          ...
# 64369             21             Basic       Quarterly          947
# 64370             22          Standard          Annual          923
# 64371             30           Premium         Monthly          327
# 64372             22          Standard         Monthly          540
# 64373             25          Standard         Monthly          696
#
#        Last Interaction Churn
# 0                     9   Yes
# 1                    20    No
# 2                    21    No
# 3                    18    No
# 4                    18    No
# ...                 ...   ...
# 64369                14   Yes
# 64370                 9   Yes
# 64371                20   Yes
# 64372                13   Yes
# 64373                22   Yes
#
# [64374 rows x 12 columns]

# %%
df.info() #displaying the information about the DataFrame.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64374 entries, 0 to 64373
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         64374 non-null  int64
#  1   Age                64374 non-null  int64
#  2   Gender             64374 non-null  object
#  3   Tenure             64374 non-null  int64
#  4   Usage Frequency    64374 non-null  int64
#  5   Support Calls      64374 non-null  int64
#  6   Payment Delay      64374 non-null  int64
#  7   Subscription Type  64374 non-null  object
#  8   Contract Length    64374 non-null  object
#  9   Total Spend        64374 non-null  int64
#  10  Last Interaction   64374 non-null  int64
#  11  Churn              64374 non-null  object
# dtypes: int64(8), object(4)
# memory usage: 5.9+ MB

# %%
df.duplicated().sum() #checking for the number of duplicate rows in the DataFrame.
# Out:
# 0

# %%
df.isnull().sum() #checking for the number of missing values in the DataFrame.
# Out:
# CustomerID           0
# Age                  0
# Gender               0
# Tenure               0
# Usage Frequency      0
# Support Calls        0
# Payment Delay        0
# Subscription Type    0
# Contract Length      0
# Total Spend          0
# Last Interaction     0
# Churn                0
# dtype: int64

# %%
df.columns #displaying the columns in the DataFrame.
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Tenure', 'Usage Frequency',
#        'Support Calls', 'Payment Delay', 'Subscription Type',
#        'Contract Length', 'Total Spend', 'Last Interaction', 'Churn'],
#       dtype='object')

# %%
df.describe() #displaying the summary statistics of the DataFrame.
# Out:
#          CustomerID           Age        Tenure  Usage Frequency  \
# count  64374.000000  64374.000000  64374.000000     64374.000000
# mean   32187.500000     41.970982     31.994827        15.080234
# std    18583.317451     13.924911     17.098234         8.816470
# min        1.000000     18.000000      1.000000         1.000000
# 25%    16094.250000     30.000000     18.000000         7.000000
# 50%    32187.500000     42.000000     33.000000        15.000000
# 75%    48280.750000     54.000000     47.000000        23.000000
# max    64374.000000     65.000000     60.000000        30.000000
#
#        Support Calls  Payment Delay   Total Spend  Last Interaction
# count   64374.000000   64374.000000  64374.000000      64374.000000
# mean        5.400690      17.133952    541.023379         15.498850
# std         3.114005       8.852211    260.874809          8.638436
# min         0.000000       0.000000    100.000000          1.000000
# 25%         3.000000      10.000000    313.000000          8.000000
# 50%         6.000000      19.000000    534.000000         15.000000
# 75%         8.000000      25.000000    768.000000         23.000000
# max        10.000000      30.000000   1000.000000         30.000000

# %%
# check the unique values in each variable

for i in df.columns:
    print('No. of unique values in', i, 'are:', df[i].nunique())
# Out:
# No. of unique values in CustomerID are: 64374
# No. of unique values in Age are: 48
# No. of unique values in Gender are: 2
# No. of unique values in Tenure are: 60
# No. of unique values in Usage Frequency are: 30
# No. of unique values in Support Calls are: 11
# No. of unique values in Payment Delay are: 31
# No. of unique values in Subscription Type are: 3
# No. of unique values in Contract Length are: 3
# No. of unique values in Total Spend are: 901
# No. of unique values in Last Interaction are: 30
# No. of unique values in Churn are: 2

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
sns.boxplot(x='Churn', y='Age', data=df)
plt.xlabel('Churn')
plt.ylabel('Age')
plt.title('Age Distribution by Churn')
plt.show()

#A boxplot compares the Age distribution between churned and non-churned customers

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\rog zephyrus g15\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rog zephyrus g15\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rog zephyrus g15\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\rog zephyrus g15\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(data=df, x='Age', hue='Churn', common_norm=False, fill=True, palette='Set2')
plt.xlabel('Age')
plt.ylabel('Density')
plt.title('Age Distribution by Churn')
plt.show()
#The **KDE plot** shows the smooth **Age** distribution for churned vs. non-churned customers, helping to compare their density patterns.
# 1 churned customers or 0 non-churned customers

# %%
plt.figure(figsize=(6, 6))
gender_counts = df['Gender'].value_counts()
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%')
plt.title('Gender Distribution of Customers')
plt.show()

#represents the percentage of churned and non-churned customers, showing that the dataset is balanced

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.select_dtypes(include='number').corr(), annot=True, cmap='Blues', fmt='.2f')
plt.title('Feature Correlation Heatmap')
plt.show()

# 1 strong positive
# -1 strong negative
# 0 no correlation or on relationship between the features

# %%
# Identify numerical and categorical columns
numerical = []
categorical = []
columns_to_drop = ['CustomerID', 'Gender']
target = 'Churn'

for column in df.columns:
    if column == target or column in columns_to_drop:
        continue
    if df[column].dtype != 'O': 
        numerical.append(column)
    else:
        categorical.append(column)

# %%
# Drop unnecessary columns
def drop_column(x):
    return x.drop(columns=columns_to_drop)

# %%
categorical
# Out:
# ['Subscription Type', 'Contract Length']

# %%
numerical
# Out:
# ['Age',
#  'Tenure',
#  'Usage Frequency',
#  'Support Calls',
#  'Payment Delay',
#  'Total Spend',
#  'Last Interaction']

# %%
# df[categorical].describe()

# %%
# df[numerical].describe()

# %%
#transforming the categorical columns into numerical columns using OneHotEncoder.
OneHotEncoder().fit_transform(df[categorical])
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 128748 stored elements and shape (64374, 6)>

# %%
from sklearn.preprocessing import OrdinalEncoder
#transforming the categorical columns into numerical columns using OrdinalEncoder.
OrdinalEncoder().fit_transform(df[categorical])
# Out:
# array([[0., 1.],
#        [2., 1.],
#        [1., 0.],
#        ...,
#        [1., 1.],
#        [2., 1.],
#        [2., 1.]])

# %%
# Transformers for numerical and categorical features
numerical_transformer = Pipeline([
    ('impute', SimpleImputer(strategy='median')),
    ('scaling', StandardScaler())
])

categorical_transformer = Pipeline([
    ('impute', SimpleImputer(strategy='most_frequent')),
    ('encoding', OneHotEncoder())
])

# %%
# Preprocessing pipeline
preprocessor = ColumnTransformer([
    ('numerical', numerical_transformer, numerical),
    ('categorical', categorical_transformer, categorical)
])

pipeline = Pipeline([
    ('drop', FunctionTransformer(drop_column)),
    ('prepro', preprocessor)
])

# %%
# Fit and transform the data
preprocessor.fit_transform(df)
# Out:
# array([[-1.43420211, -0.40909964, -0.12252553, ...,  0.        ,
#          1.        ,  0.        ],
#        [-0.0697304 , -0.23364156,  1.46542392, ...,  0.        ,
#          1.        ,  0.        ],
#        [ 0.36115541, -0.29212759, -0.57622537, ...,  1.        ,
#          0.        ,  0.        ],
#        ...,
#        [-1.21875921,  0.40970473, -0.12252553, ...,  0.        ,
#          1.        ,  0.        ],
#        [ 0.57659831, -0.81850183,  0.44459927, ...,  0.        ,
#          1.        ,  0.        ],
#        [ 0.72022691,  0.76062088, -0.00910057, ...,  0.        ,
#          1.        ,  0.        ]])

# %%
# Training pipelines for different models
training_pipeline_Forest = Pipeline([
    ('drop_columns', FunctionTransformer(drop_column)),
    ('preprocessing', preprocessor),
    ('model', RandomForestClassifier())
])

training_pipeline_Logic = Pipeline([
    ('drop_columns', FunctionTransformer(drop_column)),
    ('preprocessing', preprocessor),
    ('model', LogisticRegression())
])

training_pipeline_SVM = Pipeline([
    ('drop_columns', FunctionTransformer(drop_column)),
    ('preprocessing', preprocessor),
    ('model', SVC())
])

training_pipeline_DecisionTree = Pipeline([
    ('drop_columns', FunctionTransformer(drop_column)),
    ('preprocessing', preprocessor),
    ('model', DecisionTreeClassifier())
])

# %%
# Split the data into training and testing sets
x, y = df.drop(columns=target), df[target]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Model training
training_pipeline_DecisionTree.fit(x_train, y_train)
training_pipeline_Forest.fit(x_train, y_train)
training_pipeline_Logic.fit(x_train, y_train)
training_pipeline_SVM.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('drop_columns',
#                  FunctionTransformer(func=<function drop_column at 0x00000269735854E0>)),
#                 ('preprocessing',
#                  ColumnTransformer(transformers=[('numerical',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaling',
#                                                                    StandardScaler())]),
#                                                   ['Age', 'Tenure',
#                                                    'Usage Frequency',
#                                                    'Support Calls',
#                                                    'Payment Delay',
#                                                    'Total Spend',
#                                                    'Last Interaction']),
#                                                  ('categorical',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoding',
#                                                                    OneHotEncoder())]),
#                                                   ['Subscription Type',
#                                                    'Contract Length'])])),
#                 ('model', SVC())])

# %%
# Predictions
y_predictionTree = training_pipeline_DecisionTree.predict(x_test)
y_predictionLogic = training_pipeline_Logic.predict(x_test)
y_predictionSVM = training_pipeline_SVM.predict(x_test)
y_predictionForest = training_pipeline_Forest.predict(x_test)

# %%
# Save the models
cmforest = confusion_matrix(y_test,y_predictionTree)
cmlogic = confusion_matrix(y_test,y_predictionLogic)
cmtree = confusion_matrix(y_test,y_predictionSVM)
cmSvm = confusion_matrix(y_test,y_predictionForest)

# %%
# Save the models
cmforest
# Out:
# array([[6379,  414],
#        [ 482, 5600]], dtype=int64)

# %%
cmlogic
# Out:
# array([[5590, 1203],
#        [1086, 4996]], dtype=int64)

# %%
cmtree
# Out:
# array([[5947,  846],
#        [ 370, 5712]], dtype=int64)

# %%
cmSvm
# Out:
# array([[6228,  565],
#        [  51, 6031]], dtype=int64)

# %%
import joblib 
joblib.dump(Pipeline, 'preprocessor_airline.pkl')
# Out:
# ['preprocessor_airline.pkl']

# %%
# Convert target labels to numeric if necessary
y_train = y_train.replace({'No': 0, 'Yes': 1})
y_test = y_test.replace({'No': 0, 'Yes': 1})
# Out:
# C:\Users\ROG Zephyrus G15\AppData\Local\Temp\ipykernel_20924\1904184130.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   y_train = y_train.replace({'No': 0, 'Yes': 1})
# C:\Users\ROG Zephyrus G15\AppData\Local\Temp\ipykernel_20924\1904184130.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   y_test = y_test.replace({'No': 0, 'Yes': 1})

# %%
# Ensure x_train and x_test are arrays after preprocessing
x_train_transformed = preprocessor.fit_transform(x_train)
x_test_transformed = preprocessor.transform(x_test)

# %%
# Input shape fix
input_shape = x_train_transformed.shape[1]

# %%
input_shape #number of columns in the x_train_transformed array.
# Out:
# 13

# %%
# Updated neural network model
model = Sequential([
    InputLayer(input_shape=(input_shape,)),
    Dense(512, activation="relu"),
    Dense(256, activation="relu"),
    Dense(128, activation="relu"),
    Dense(64, activation="relu"),
    Dense(32, activation="relu"),
    Dense(8, activation="relu"),
    Dense(1, activation='sigmoid')  # Output layer for binary classification
])
# Out:
# WARNING:tensorflow:From c:\Users\ROG Zephyrus G15\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(x_train_transformed, y_train, epochs=50, validation_data=(x_test_transformed, y_test))
# Out:
# Epoch 1/50
# 1610/1610 [==============================] - 4s 2ms/step - loss: 0.0829 - accuracy: 0.9595 - val_loss: 0.1397 - val_accuracy: 0.9442
# Epoch 2/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0817 - accuracy: 0.9603 - val_loss: 0.1358 - val_accuracy: 0.9443
# Epoch 3/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0800 - accuracy: 0.9610 - val_loss: 0.1522 - val_accuracy: 0.9426
# Epoch 4/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0810 - accuracy: 0.9607 - val_loss: 0.1406 - val_accuracy: 0.9456
# Epoch 5/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0787 - accuracy: 0.9618 - val_loss: 0.1463 - val_accuracy: 0.9409
# Epoch 6/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0782 - accuracy: 0.9618 - val_loss: 0.1430 - val_accuracy: 0.9385
# Epoch 7/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0748 - accuracy: 0.9631 - val_loss: 0.1592 - val_accuracy: 0.9370
# Epoch 8/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0754 - accuracy: 0.9639 - val_loss: 0.1698 - val_accuracy: 0.9409
# Epoch 9/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0746 - accuracy: 0.9638 - val_loss: 0.1832 - val_accuracy: 0.9362
# Epoch 10/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0749 - accuracy: 0.9635 - val_loss: 0.1617 - val_accuracy: 0.9373
# Epoch 11/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0718 - accuracy: 0.9654 - val_loss: 0.1905 - val_accuracy: 0.9365
# Epoch 12/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0725 - accuracy: 0.9652 - val_loss: 0.1618 - val_accuracy: 0.9386
# Epoch 13/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0716 - accuracy: 0.9657 - val_loss: 0.1590 - val_accuracy: 0.9332
# Epoch 14/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0694 - accuracy: 0.9666 - val_loss: 0.1849 - val_accuracy: 0.9382
# Epoch 15/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0700 - accuracy: 0.9673 - val_loss: 0.1673 - val_accuracy: 0.9400
# Epoch 16/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0676 - accuracy: 0.9678 - val_loss: 0.1839 - val_accuracy: 0.9392
# Epoch 17/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0688 - accuracy: 0.9676 - val_loss: 0.1931 - val_accuracy: 0.9265
# Epoch 18/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0658 - accuracy: 0.9696 - val_loss: 0.1872 - val_accuracy: 0.9321
# Epoch 19/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0660 - accuracy: 0.9693 - val_loss: 0.1744 - val_accuracy: 0.9357
# Epoch 20/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0624 - accuracy: 0.9701 - val_loss: 0.2042 - val_accuracy: 0.9294
# Epoch 21/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0631 - accuracy: 0.9708 - val_loss: 0.2403 - val_accuracy: 0.9270
# Epoch 22/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0613 - accuracy: 0.9709 - val_loss: 0.2009 - val_accuracy: 0.9351
# Epoch 23/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0637 - accuracy: 0.9707 - val_loss: 0.1941 - val_accuracy: 0.9355
# Epoch 24/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0588 - accuracy: 0.9718 - val_loss: 0.2274 - val_accuracy: 0.9370
# Epoch 25/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0590 - accuracy: 0.9720 - val_loss: 0.1925 - val_accuracy: 0.9318
# Epoch 26/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0568 - accuracy: 0.9741 - val_loss: 0.2017 - val_accuracy: 0.9333
# Epoch 27/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0573 - accuracy: 0.9740 - val_loss: 0.2590 - val_accuracy: 0.9342
# Epoch 28/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0571 - accuracy: 0.9746 - val_loss: 0.2358 - val_accuracy: 0.9320
# Epoch 29/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0567 - accuracy: 0.9744 - val_loss: 0.2289 - val_accuracy: 0.9360
# Epoch 30/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0571 - accuracy: 0.9750 - val_loss: 0.2265 - val_accuracy: 0.9339
# Epoch 31/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0533 - accuracy: 0.9753 - val_loss: 0.2187 - val_accuracy: 0.9366
# Epoch 32/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0541 - accuracy: 0.9760 - val_loss: 0.2348 - val_accuracy: 0.9334
# Epoch 33/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0537 - accuracy: 0.9758 - val_loss: 0.2326 - val_accuracy: 0.9315
# Epoch 34/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0499 - accuracy: 0.9770 - val_loss: 0.2413 - val_accuracy: 0.9355
# Epoch 35/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0513 - accuracy: 0.9769 - val_loss: 0.2291 - val_accuracy: 0.9364
# Epoch 36/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0517 - accuracy: 0.9777 - val_loss: 0.2595 - val_accuracy: 0.9336
# Epoch 37/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0489 - accuracy: 0.9783 - val_loss: 0.2420 - val_accuracy: 0.9320
# Epoch 38/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0494 - accuracy: 0.9777 - val_loss: 0.2370 - val_accuracy: 0.9303
# Epoch 39/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0485 - accuracy: 0.9789 - val_loss: 0.2750 - val_accuracy: 0.9330
# Epoch 40/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0479 - accuracy: 0.9796 - val_loss: 0.2465 - val_accuracy: 0.9334
# Epoch 41/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0458 - accuracy: 0.9793 - val_loss: 0.2520 - val_accuracy: 0.9351
# Epoch 42/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0450 - accuracy: 0.9801 - val_loss: 0.2785 - val_accuracy: 0.9340
# Epoch 43/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0434 - accuracy: 0.9812 - val_loss: 0.2727 - val_accuracy: 0.9369
# Epoch 44/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0447 - accuracy: 0.9805 - val_loss: 0.2952 - val_accuracy: 0.9319
# Epoch 45/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0424 - accuracy: 0.9815 - val_loss: 0.2982 - val_accuracy: 0.9345
# Epoch 46/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0413 - accuracy: 0.9827 - val_loss: 0.3094 - val_accuracy: 0.9275
# Epoch 47/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0412 - accuracy: 0.9827 - val_loss: 0.3343 - val_accuracy: 0.9335
# Epoch 48/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0430 - accuracy: 0.9819 - val_loss: 0.2846 - val_accuracy: 0.9334
# Epoch 49/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0410 - accuracy: 0.9822 - val_loss: 0.2860 - val_accuracy: 0.9326
# Epoch 50/50
# 1610/1610 [==============================] - 3s 2ms/step - loss: 0.0389 - accuracy: 0.9829 - val_loss: 0.2749 - val_accuracy: 0.9292

# %%
x_train_transformed #displaying the x_train_transformed array.
# Out:
# array([[ 1.00748863,  0.58691645, -0.46172589, ...,  0.        ,
#          0.        ,  1.        ],
#        [ 0.86400944,  1.63912853, -1.14230525, ...,  0.        ,
#          0.        ,  1.        ],
#        [-0.78600122, -1.16677034, -1.48259492, ...,  1.        ,
#          0.        ,  0.        ],
#        ...,
#        [-0.64252203,  0.87919758, -0.68858568, ...,  0.        ,
#          0.        ,  1.        ],
#        [-1.28817837,  1.46375985,  0.44571325, ...,  1.        ,
#          0.        ,  0.        ],
#        [-0.64252203,  0.11926664,  0.44571325, ...,  0.        ,
#          0.        ,  1.        ]])

# %%
model.save('model.keras') #saving the model.

# %%
x_test_transformed.shape
# Out:
# (12875, 13)

# %%
x_test_transformed #displaying the x_test_transformed array.
# Out:
# array([[ 0.93574903, -0.69912053,  1.01286271, ...,  0.        ,
#          1.        ,  0.        ],
#        [-1.00122   , -0.28992695,  1.69344206, ...,  0.        ,
#          0.        ,  1.        ],
#        [ 1.65314497,  1.63912853,  0.21885346, ...,  0.        ,
#          0.        ,  1.        ],
#        ...,
#        [ 0.72053025,  1.05456626, -0.91544546, ...,  0.        ,
#          0.        ,  1.        ],
#        [-1.57513675,  1.40530362,  1.1262926 , ...,  1.        ,
#          0.        ,  0.        ],
#        [ 0.2183531 ,  0.93765381,  0.67257303, ...,  0.        ,
#          1.        ,  0.        ]])

# %%
model.predict(x_test_transformed)

# Load the model
# Out:
# 403/403 [==============================] - 0s 833us/step
# array([[0.000000e+00],
#        [0.000000e+00],
#        [1.000000e+00],
#        ...,
#        [1.000000e+00],
#        [2.759212e-07],
#        [3.397357e-11]], dtype=float32)

# %%
# Make predictions on the test data
y_pred = model.predict(x_test_transformed)

# Convert the probabilities to binary class predictions (0 or 1)
y_pred_class = (y_pred > 0.5).astype(int)  # Assuming binary classification with a threshold of 0.5

# Now you can generate and display the confusion matrix

cm = confusion_matrix(y_test, y_pred_class)

print(cm)
# Out:
# 403/403 [==============================] - 0s 809us/step
# [[6348  445]
#  [ 467 5615]]

# %%
y_test
# Out:
# 15476    0
# 34666    0
# 50474    1
# 7984     0
# 20227    0
#         ..
# 15815    0
# 23037    0
# 55566    1
# 22749    0
# 31651    0
# Name: Churn, Length: 12875, dtype: int64

# %%
y_pred[:, 0] > 0.5
# Out:
# array([False, False,  True, ...,  True, False, False])

# %%
y_pred
# Out:
# array([[0.000000e+00],
#        [0.000000e+00],
#        [1.000000e+00],
#        ...,
#        [1.000000e+00],
#        [2.759212e-07],
#        [3.397357e-11]], dtype=float32)

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(classification_report(y_test,y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93      6793
#            1       0.93      0.92      0.92      6082
#
#     accuracy                           0.93     12875
#    macro avg       0.93      0.93      0.93     12875
# weighted avg       0.93      0.93      0.93     12875

# %%
loss, accuracy = model.evaluate(x_test_transformed, y_test)
# Out:
# 403/403 [==============================] - 0s 819us/step - loss: 0.2749 - accuracy: 0.9292

# %%
loss
# Out:
# 0.274852991104126

# %%
accuracy
# Out:
# 0.9291650652885437

# %%
df
# Out:
#        CustomerID  Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0               1   22  Female      25               14              4
# 1               2   41  Female      28               28              7
# 2               3   47    Male      27               10              2
# 3               4   35    Male       9               12              5
# 4               5   53  Female      58               24              9
# ...           ...  ...     ...     ...              ...            ...
# 64369       64370   45  Female      33               12              6
# 64370       64371   37    Male       6                1              5
# 64371       64372   25    Male      39               14              8
# 64372       64373   50  Female      18               19              7
# 64373       64374   52  Female      45               15              9
#
#        Payment Delay Subscription Type Contract Length  Total Spend  \
# 0                 27             Basic         Monthly          598
# 1                 13          Standard         Monthly          584
# 2                 29           Premium          Annual          757
# 3                 17           Premium       Quarterly          232
# 4                  2          Standard          Annual          533
# ...              ...               ...             ...          ...
# 64369             21             Basic       Quarterly          947
# 64370             22          Standard          Annual          923
# 64371             30           Premium         Monthly          327
# 64372             22          Standard         Monthly          540
# 64373             25          Standard         Monthly          696
#
#        Last Interaction Churn
# 0                     9   Yes
# 1                    20    No
# 2                    21    No
# 3                    18    No
# 4                    18    No
# ...                 ...   ...
# 64369                14   Yes
# 64370                 9   Yes
# 64371                20   Yes
# 64372                13   Yes
# 64373                22   Yes
#
# [64374 rows x 12 columns]

# %%
df.iloc[:, [8]]
# Out:
#       Contract Length
# 0             Monthly
# 1             Monthly
# 2              Annual
# 3           Quarterly
# 4              Annual
# ...               ...
# 64369       Quarterly
# 64370          Annual
# 64371         Monthly
# 64372         Monthly
# 64373         Monthly
#
# [64374 rows x 1 columns]
